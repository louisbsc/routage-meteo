# %%
import numpy as np
import matplotlib.pyplot as plt
import time

import inputs.vents as v
import inputs.polaires as p
import core.isochrone as iso

# %%
VENT = v.vent_constant
v.aff_vent_static(VENT, 0, [-100, 100], [-100, 100], 50)

# %%
POLAIRE = p.polaire("data/polaires/vector.csv")

# %%
# %matplotlib qt

# %%
(N, p_dep, p_arr, t, dt, n, V, P, k_voisins, ang, dang, delta)

# %%
L = iso.n_iso(N = 5, p_dep = [0, 0, 0, 0], p_arr = [0, 20], t = 0, dt = 1, n = 100, V = VENT, P = POLAIRE, k_voisins = 20, ang = np.pi/2, dang = 0, delta = 0.5)
# Out:
# nombre isochrones : 0, temps : 0.00 heures, nombre de points : 1
# nombre isochrones : 1, temps : 1.00 heures, nombre de points : 100
# nombre isochrones : 2, temps écoulé : 2.00 heures, nombre de points : 76
# nombre isochrones : 3, temps écoulé : 3.00 heures, nombre de points : 129
# nombre isochrones : 4, temps écoulé : 4.00 heures, nombre de points : 197
# nombre isochrones : 5, temps écoulé : 5.00 heures, nombre de points : 279

# %%
for i in range(len(L)):
    plt.plot(L[L[:, 2] == i][:, 0], L[L[:, 2] == i][:, 1], c = 'blue')
    #plt.scatter([p[0] for p in l], [p[1] for p in l], c = 'blue')

plt.axis('equal')
# vents.aff_vent_static(VENT, 20, [-40, 0], [-40, 0], 20)
# Out:
# (np.float64(-23.83333333333334),
#  np.float64(23.83333333333334),
#  np.float64(-2.7495201260219244),
#  np.float64(11.07135111894165))

# %%
p_dep = [-20, -20, 0, 0]
p_arr = [20, -20]
route = iso.toutes_iso(p_dep, p_arr, t = 0, dt = 0.2, n = 80, V = VENT, P = POLAIRE, e_arr = 1, r = 0.5, ang = np.pi / 2, dang = np.radians(1), delta = 0.5)

r = route[1]
L = route[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 p_dep = [-20, -20, 0, 0]
#       2 p_arr = [20, -20]
# ----> 3 route = iso.toutes_iso(p_dep, p_arr, t = 0, dt = 0.2, n = 80, V = VENT, P = POLAIRE, e_arr = 1, r = 0.5, ang = np.pi / 2, dang = np.radians(1), delta = 0.5)
#       5 r = route[1]
#       6 L = route[0]
#
# TypeError: toutes_iso() got an unexpected keyword argument 'ang'

# %%
#%matplotlib qt

# %%
import matplotlib.pyplot as plt

plt.plot(r[:, 0], r[:, 1], c = 'red')
for i in range(len(L)):
   l = L[L[:, 2] == i]
   plt.plot(l[:, 0], l[:, 1], c = 'blue')


plt.axis('equal')

vents.aff_vent_static(VENT, 20, [-30, 30], [-40, 0], 20)

# %%
import courants

VENT = vents.V1
COURANT = courants.C0

# %%
vents.aff_vent_static(VENT, 20, [-40, 0], [-40, 0], 20)

# %%
L = iso.n_iso(N = 10, p_dep = [-20, -20, 0, 0], t = 0, dt = 0.25, n = 80, V = VENT, P = POLAIRE, r = 0.5, dir = 0, ang = np.pi / 2, dang = np.radians(1), delta = 0.5)
