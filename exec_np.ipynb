# %%
import numpy as np
import matplotlib.pyplot as plt
import time

import vents_np
import polaires_np
import isochrone_np as iso
import env_concave_np as env
import fonctions_utiles_np as f

# %%
#VENT = vents_np.V1
VENT = vents_np.vent_circulaire_2


vents_np.vent(VENT, 0, [-100, 100], [-100, 100], 50)

# %%
POLAIRE = polaires_np.Vector_vect

# %%
L = iso.niso_np(p = [-20, -20, 0, 0], t = 0, N = 10, dt = 0.25, n = 80, V = VENT, P = POLAIRE)
# Out:
# nombre isochrones : 3, temps écoulé : 0.25 heures, nombre de points : 118
# nombre isochrones : 4, temps écoulé : 0.50 heures, nombre de points : 179
# nombre isochrones : 5, temps écoulé : 0.75 heures, nombre de points : 238
# nombre isochrones : 6, temps écoulé : 1.00 heures, nombre de points : 294
# nombre isochrones : 7, temps écoulé : 1.25 heures, nombre de points : 353
# nombre isochrones : 8, temps écoulé : 1.50 heures, nombre de points : 410
# nombre isochrones : 9, temps écoulé : 1.75 heures, nombre de points : 463
# nombre isochrones : 10, temps écoulé : 2.00 heures, nombre de points : 515

# %%
for i in range(len(L)):
    plt.plot(L[L[:, 2] == i][:, 0], L[L[:, 2] == i][:, 1], c = 'blue')
    #plt.scatter([p[0] for p in l], [p[1] for p in l], c = 'blue')

plt.axis('equal')
vents_np.vent(VENT, 20, [-40, 0], [-40, 0], 20)

# %%
p_dep = [-20, -20, 0, 0]
p_arr = [20, -20]
route = iso.toutesiso_np(p_dep, p_arr, t = 0, dt = 0.25, n = 80, V = VENT, P = POLAIRE, e_arr = 1)

r = route[1]
L = route[0]
# Out:
# nombre isochrones : 3, temps écoulé : 0.25 heures, nombre de points : 118
# nombre isochrones : 4, temps écoulé : 0.50 heures, nombre de points : 179
# nombre isochrones : 5, temps écoulé : 0.75 heures, nombre de points : 238
# nombre isochrones : 6, temps écoulé : 1.00 heures, nombre de points : 294
# nombre isochrones : 7, temps écoulé : 1.25 heures, nombre de points : 353
# nombre isochrones : 8, temps écoulé : 1.50 heures, nombre de points : 410
# nombre isochrones : 9, temps écoulé : 1.75 heures, nombre de points : 463
# nombre isochrones : 10, temps écoulé : 2.00 heures, nombre de points : 515
# nombre isochrones : 11, temps écoulé : 2.25 heures, nombre de points : 567
# nombre isochrones : 12, temps écoulé : 2.50 heures, nombre de points : 618
# nombre isochrones : 13, temps écoulé : 2.75 heures, nombre de points : 670
# nombre isochrones : 14, temps écoulé : 3.00 heures, nombre de points : 718
# nombre isochrones : 15, temps écoulé : 3.25 heures, nombre de points : 770
# ...

# %%
# %matplotlib qt
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(r[:, 0], r[:, 1], c = 'red')
#for i in range(len(L)):
#    l = L[L[:, 2] == i]
#    plt.plot(l[:, 0], l[:, 1], c = 'blue')


plt.axis('equal')

vents_np.vent(VENT, 20, [-30, 30], [-40, 0], 20)
